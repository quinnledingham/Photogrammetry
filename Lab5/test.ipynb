# %%
import importlib
import lab5_calc
# Out:
# <module 'lab5_calc' from 's:\\ENGO634\\Lab5\\lab5_calc.py'>

# %%
importlib.reload(lab5_calc)
res_27, res_28 = lab5_calc.do_single_photo_resection()
# Out:
# Approximated Parameters: [np.float64(74.20259049525617), np.float64(-632.4508779070171), np.float64(1840.788980613418), 0.0, 0.0, np.float64(90.01237877652383)]
# Iterations: 3
# Estimated Parameters: [  74.2025905  -632.45087791 1840.78898061    0.            0.
#  5157.32940783]
# Residuals: [-0.01918207 -0.03992046 -0.01263509 -0.00239432 -0.01466087  0.0046004
#   0.04678028  0.03845577]
# RMS x: 0.02706904558920863
# RMS y: 0.027836064517751974
# Redundancy Numbers: [0.60526956 0.266252   0.17240251 0.11671086 0.06196449 0.0051465
#  0.40304333 0.36921074] Sum: 2.0000000000001013
# other: [np.float64(0.02706904558920863), np.float64(0.027836064517751974), np.float64(2.0000000000001013), np.float64(3.6606978289781558)]
# Correlation Matrix of Estimated Parameters:
#  [[ 1.         -0.83625812 -0.85284042  0.85135306  0.99614417  0.64992433]
#  [-0.83625812  1.          0.9149247  -0.99653557 -0.84779325 -0.55614542]
# ...

# %%
importlib.reload(lab5_calc)
lab5_calc.do_space_intersection(res_27, res_28)
# Out:
# mean_height: + 1087.1180791690756
# residuals: [ 0.34628897  0.10770319 -0.2717022  -0.31924478  0.28590193  0.22069024
#  -0.14077349 -0.20888751  0.2687464   0.15160106 -0.20151793 -0.27199651
#   0.2422914   0.22126476 -0.08681258 -0.34355295]
# RMSE: 0.2429220499261709
